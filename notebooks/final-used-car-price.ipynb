# %% [markdown]
# # Import libraries

# %%
import warnings
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats

from xgboost import XGBRegressor
from sklearn.ensemble import ExtraTreesRegressor, VotingRegressor, StackingRegressor, GradientBoostingRegressor
from cuml.ensemble import RandomForestRegressor
from cuml.linear_model import LinearRegression
from cuml.neighbors import KNeighborsRegressor

from sklearn.preprocessing import OneHotEncoder, StandardScaler, QuantileTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from cuml.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_validate, RandomizedSearchCV, GridSearchCV, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
from scipy.stats import boxcox

from colorama import Fore, Back, Style

sns.set_style('white')
warnings.filterwarnings('ignore')
pd.options.display.float_format="{:.2f}".format

# %% [markdown]
# # EDA & Data Preprocessing

# %%
df = pd.read_csv('/kaggle/input/uncovering-factors-that-affect-used-car-prices/autos.csv').drop('index', axis=1)
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
#  15  notRepairedDamage    299468 non-null  object
#  16  dateCreated          371528 non-null  object
#  17  nrOfPictures         371528 non-null  int64
#  18  postalCode           371528 non-null  int64
#  19  lastSeen             371528 non-null  object
# dtypes: int64(7), object(13)
# memory usage: 56.7+ MB

# %%
plt.figure(figsize=(18, 6))

notnull_counts = df.notnull().sum().sort_values(ascending=True)

fig = sns.barplot(x=notnull_counts.index, y=notnull_counts.values, palette='viridis')

for index, value in enumerate(notnull_counts.values):
    plt.text(index, value + 0.02 * max(notnull_counts.values), f"{value}", ha='center', fontsize=9)

plt.xticks(rotation=45, ha='right')  
plt.xlabel("Columns")
plt.ylabel("Non-null count")  
plt.title("Count of Non-null Values in Each Column")
plt.show()

# %% [markdown]
# ## Insights
# - ### **Missing Values:**
#
#     - **`vehicleType` has 37869 (10.2%) missing values**
#     - **`gearbox` has 20209 (5.4%) missing values**
#     - **`model` has 20484 (5.5%) missing values**
#     - **`fuelType` has 33386 (9.0%) missing values**
#     - **`notRepairedDamage` has 72060 (19.4%) missing values**
#
#
# - ### **DateTime**
#     - **Dtype of `dateCrawled`. `lastSeen`, and `dateCreated` columns is object --> Convert to DateTime**
#
#
# - ### **Zeros**
#
#     - **`price` has 10778 (2.9%) zeros**
#     - **`powerPS` has 40820 (11.0%) zeros**
#     - **`monthOfRegistration` has 37675 (10.1%) zeros**
#
#
# - ### **High Correlation**
#
#     - **`price` is highly overall correlated with `yearOfRegistration` and 1 other field**
#     - **`yearOfRegistration `is highly overall correlated with `price` and 1 other field**
#     - **`powerPS` is highly overall correlated with `price`	High correlation**
#     - **`vehicleType` is highly overall correlated with `yearOfRegistration`**
#
# - ### **Other (Possible) Problems**
#     - **German categorical values --> English**
#     - **`nrOfPictures` is irrelevant --> Drop**
#     - **I think `dateCrawled` and `dateCreated` columns are the same (time doesn't matter here). These two, plus maybe even the `dateCreated` column are irrelevant**
#     - **I don't know how I feel about the `abtest` column! is it also irrelevant?**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(14, 6))

df['seller'].value_counts().plot(kind='bar', title='Seller Type',  color=['red', 'blue'], ax=axes[0], rot=30, xlabel='')

df['offerType'].value_counts().plot(kind='bar', title='Offer Type',  color=['red', 'blue'], ax=axes[1], rot=30, xlabel='')

df['abtest'].value_counts().plot(kind='bar', title='Test Type',  color=['red', 'blue'], ax=axes[2], rot=30, xlabel='')
# Out:
# <Axes: title={'center': 'Test Type'}>

# %% [markdown]
# ## Data Preprocessing
# - #### **I think later I'm gonna have to do more data preprocessing.**
# - #### **Since except for 3 rows all the other ads are private, I'm also gonna drop the `seller` column. It's basically useless.**
# - #### **As shown, the `offerTyple` column is also useless so I'm gonna drop this one, too.**
# - #### **Also, I noticed that the `yearOfRegistration` column has some odd and extreme values. So, I'm gonna define a solid range for this field. I think a range between `1980` and `2023` is decent.**
# - #### I will use Label Encoding for the categorical columns which only have 2 unique values such as **abtest**, **gearbox**, **notRepairedDamge**. For the other columns, I will use One-Hot Encoding.
# - #### **German to English:**
#     - **manuell --> Manual**
#     - **automatik --> Automatic**
#     - **ja --> Yes**
#     - **nein --> No**
#     - **benzin --> Petrol**
#     - **andere --> Other**

# %%
# 1. DateTime Conversion --> Drop 'dateCrawled' and 'lastSeen'
df.drop(['lastSeen', 'dateCrawled'], axis=1, inplace=True)
df['dateCreated'] = pd.to_datetime(df['dateCreated'])

# 2. Drop the 'nrOfPictures', 'seller', 'offerType' columns
df.drop('nrOfPictures', axis=1, inplace=True)
df.drop('seller', axis=1, inplace=True)
df.drop('offerType', axis=1, inplace=True)

# 3. Define a range for the 'yearOfRegistration'
df = df[df['yearOfRegistration'].between(1980, 2023)]

# 4. German to English, as best as I can
df['fuelType'] = df['fuelType'].map({'benzin': 'petrol', 'diesel': 'diesel', 'lpg': 'lpg', 'cng': 'cng', 'hybrid': 'hybrid', 'elektro': 'electric', 'andere': 'other'})
df['vehicleType'] = df['vehicleType'].map({'limousine': 'sedan', 'kleinwagen': 'small car', 'kombi': 'station wagon', 'bus': 'bus', 'cabrio': 'convertible', 'coupe': 'coupe', 'suv': 'suv', 'andere': 'other'})

df.head()
# Out:
#                              name  price abtest vehicleType  \
# 0                      Golf_3_1.6    480   test         NaN
# 1            A5_Sportback_2.7_Tdi  18300   test       coupe
# 2  Jeep_Grand_Cherokee_"Overland"   9800   test         suv
# 3              GOLF_4_1_4__3TÜRER   1500   test   small car
# 4  Skoda_Fabia_1.4_TDI_PD_Classic   3600   test   small car
#
#    yearOfRegistration    gearbox  powerPS  model  kilometer  \
# 0                1993    manuell        0   golf     150000
# 1                2011    manuell      190    NaN     125000
# 2                2004  automatik      163  grand     125000
# 3                2001    manuell       75   golf     150000
# 4                2008    manuell       69  fabia      90000
#
#    monthOfRegistration fuelType       brand notRepairedDamage dateCreated  \
# 0                    0   petrol  volkswagen               NaN  2016-03-24
# 1                    5   diesel        audi                ja  2016-03-24
# 2                    8   diesel        jeep               NaN  2016-03-14
# 3                    6   petrol  volkswagen              nein  2016-03-17
# 4                    7   diesel       skoda              nein  2016-03-31
#
#    postalCode
# 0       70435
# 1       66954
# 2       90480
# 3       91074
# 4       60437

# %%
colors_10_1 = sns.color_palette("Spectral", 10)
colors_10_2 = sns.color_palette("Set3", 10)
colors_5 = sns.color_palette('Accent', 5)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

df['brand'].value_counts().head(10).plot(kind='bar', title='Top 10 Brands - Ads Count', color=colors_10_1, ax=axes[0], xlabel='Brand', ylabel='Count', grid=True)
df['brand'].value_counts().tail(10).plot(kind='bar', title='Bottom 10 Brands - Ads Count', color=colors_10_1, ax=axes[1], xlabel='Brand', ylabel='Count', grid=True)
# Out:
# <Axes: title={'center': 'Bottom 10 Brands - Ads Count'}, xlabel='Brand', ylabel='Count'>

# %%
group_by_brand = df.groupby('brand')['model'].value_counts().sort_values(ascending=False)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(24, 8))

group_by_brand.head(10).plot(kind='bar', grid=True, rot=30, xlabel="(Brand, Model) Pairs", ylabel='Count', title='Top 10 Models by Brand - Ads Count', ax=axes[0], color=colors_10_2)
group_by_brand.tail(10).plot(kind='bar', grid=True, rot=30, xlabel="(Brand, Model) Pairs", ylabel='Count', title='Bottom 10 Models by Brand - Ads Count', ax=axes[1], color=colors_10_2)
# Out:
# <Axes: title={'center': 'Bottom 10 Models by Brand - Ads Count'}, xlabel='(Brand, Model) Pairs', ylabel='Count'>

# %%
group_by_vehicle_type = df.groupby('vehicleType')[['model', 'brand']].value_counts().sort_values(ascending=False)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(24, 8))

df['vehicleType'].value_counts().plot(kind='bar', color=colors_5, ax=axes[0], grid=True, rot=30, xlabel='Vehicle Type', ylabel='Count', title='')
group_by_vehicle_type.head(10).plot(kind='bar', grid=True, color=colors_10_1, ax=axes[1], title='Top 10 Cars by Vehicle Type, Brand, and Model - Ads Count')
# Out:
# <Axes: title={'center': 'Top 10 Cars by Vehicle Type, Brand, and Model - Ads Count'}, xlabel='vehicleType,model,brand'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(24, 8))

yr_mean = df['yearOfRegistration'].mean()
yr_median = df['yearOfRegistration'].median()

df['yearOfRegistration'].plot(kind='hist', bins=10, ax=axes[0], title='Histogram of the year of registration', xlabel='Year', color='blue')
axes[0].axvline(yr_mean, color='red', linestyle='dashed', linewidth=1, label='MEAN', alpha=.7)
axes[0].axvline(yr_median, color='red', linestyle='solid', linewidth=1, label='MEDIAN', alpha=.7)
axes[0].legend()

df['yearOfRegistration'].plot(kind='kde', ax=axes[1], title='KDE of the year of registration', xlabel='Year',  color='red')
axes[1].axvline(yr_mean, color='blue', linestyle='dashed', linewidth=1, label='MEAN', alpha=.5)
axes[1].axvline(yr_median, color='blue', linestyle='solid', linewidth=1, label='MEDIAN', alpha=.5)
axes[1].legend()

# %% [markdown]
# ### **I think there's also smth wrong with the `kilometer` field. As illustrated, the distribution is centered around `150K`. Also, there are no values higher than this. Plus, I think the values are not variable. Either way, I will leave this field alone and just use it as is.**
# **Min. of Kilometer: 5,000 -- Max. of Kilometer: 150,000**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(24, 8))

km_mean = df['kilometer'].mean()
km_median = df['kilometer'].median()

df['kilometer'].plot(kind='hist', bins= 5, ax=axes[0], title='Histogram of the Kilometer', xlabel='KM', color='blue')
axes[0].axvline(km_mean, color='red', linestyle='dashed', linewidth=2, label='MEAN', alpha=.5)
axes[0].axvline(km_median, color='red', linestyle='solid', linewidth=2, label='MEDIAN', alpha=.5)
axes[0].legend()

df['kilometer'].plot(kind='kde', ax=axes[1], title='KDE of the Kilometer', xlabel='KM',  color='red')
axes[1].axvline(km_mean, color='blue', linestyle='dashed', linewidth=2, label='MEAN', alpha=.5)
axes[1].axvline(km_median, color='blue', linestyle='solid', linewidth=2, label='MEDIAN', alpha=.5)
axes[1].legend()

print(f"Min. of Kilometer: {df['kilometer'].min()} -- Max. of Kilometer: {df['kilometer'].max()}\n")
# Out:
# Min. of Kilometer: 5000 -- Max. of Kilometer: 150000

# %% [markdown]
# ### **I think I should drop rows with the fuel types of `lpg`, `cng`, `hybrid`, `other` and `elektro`.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(24, 8))

df['gearbox'].value_counts().plot(kind='bar', ax=axes[0], color=['red', 'blue'], title='No. of Cars by Gearbox', xlabel='Gearbox Type', ylabel='Count', rot=30, grid=True)
df['fuelType'].value_counts().plot(kind='bar', ax=axes[1], color=['red', 'blue', 'green', 'purple'], title='No. of Cars by Fuel Type', xlabel='Fuel Type', ylabel='Count', rot=30, grid=True)
df['notRepairedDamage'].value_counts().plot(kind='bar', ax=axes[2], color=['red', 'blue', 'green'], title='Repaired/Damaged?', xlabel='Repaired/Damaged', ylabel='Count', rot=30, grid=True)
# Out:
# <Axes: title={'center': 'Repaired/Damaged?'}, xlabel='Repaired/Damaged', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(24, 8))

months = df[df['monthOfRegistration'] > 0]

months['monthOfRegistration'].plot(kind='hist', ax=axes[0], title='Histogram of the month of registration', xlabel='Month', color='blue')

months['monthOfRegistration'].plot(kind='kde', ax=axes[1], title='KDE of the month of registration', xlabel='Month', color='red')
# Out:
# <Axes: title={'center': 'KDE of the month of registration'}, ylabel='Density'>

# %% [markdown]
# ### **There's no correlation between Price and Month of registration, so I'm gonna drop it later.**

# %%
a = df[['monthOfRegistration', 'price']]
b = df[['yearOfRegistration', 'price']]
methods = ['kendall', 'spearman', 'pearson']

fig, axes = plt.subplots(3, 2, figsize=(14, 14), sharey=True)
fig.suptitle('Correlations', fontweight='bold', fontsize='14')

for i in range(3):
        
    sns.heatmap(a.corr(method=methods[i]), annot=True, ax=axes[i,0])
    axes[i,0].set_title(f"Price vs. Month of Registration ({methods[i]})")

    sns.heatmap(b.corr(method=methods[i]), annot=True, ax=axes[i,1])
    axes[i,1].set_title(f"Price vs. Year of Registration ({methods[i]})")

# %% [markdown]
# ### **The range of the `price` bothers me:**
#
# - **No. of cars with a price value higher than 20K: 16,469**
# - **No. of cars with a price value higher than 30K: 5,556**
# - **No. of cars with a price value higher than 40K: 2,501**
# - **Mean of price: 16,611.7, Median of price: 2,944.0**
# - **Min. price: 0, Max. price: 2,147,483,647**

# %%
print(f"No. of cars with a price value higher than 20K: {Style.BRIGHT}{len(df[df['price'] > 20_000])}")
print(f"{Style.RESET_ALL}No. of cars with a price value higher than 30K: {Style.BRIGHT}{len(df[df['price'] > 30_000])}")
print(f"{Style.RESET_ALL}No. of cars with a price value higher than 40K: {Style.BRIGHT}{len(df[df['price'] > 40_000])}")
print(f"{Style.RESET_ALL}Mean of price: {Style.BRIGHT}{df['price'].mean():.2f}{Style.RESET_ALL}, Median of price: {Style.BRIGHT}{df['price'].median()}")
print(f"{Style.RESET_ALL}Min. price: {Style.BRIGHT}{df['price'].min()}{Style.RESET_ALL}, Max. price: {Style.BRIGHT}{df['price'].max()}")
# Out:
# No. of cars with a price value higher than 20K: 16469
# No. of cars with a price value higher than 30K: 5556
# No. of cars with a price value higher than 40K: 2501
# Mean of price: 16611.71, Median of price: 2944.0
# Min. price: 0, Max. price: 2147483647

# %% [markdown]
# ### **As shown, the range of `[200, 20K]` is better than the other two and it eliminates a largre proportion of outliers. We can go even lower, but I don't like doing so. Just remember that the prices are skewed.**

# %%
df['price'].quantile(.95), df['price'].quantile(.05)
# Out:
# (19500.0, 200.0)

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(24, 12))

bins = 10

price_20 = df.loc[df['price'].between(200, 20_000), 'price']
price_30 = df.loc[df['price'].between(200, 30_000), 'price']
price_40 = df.loc[df['price'].between(200, 40_000), 'price']

price_20.plot(kind='hist', bins=bins, ax=axes[0,0], title='Histogram of Price in Range [200, 20K]', xlabel='Price', color=colors_5[0])
axes[0,0].axvline(price_20.mean(), color='red', linestyle='dashed', linewidth=2, label='MEAN', alpha=.5)
axes[0,0].axvline(price_20.median(), color='red', linestyle='solid', linewidth=2, label='MEDIAN', alpha=.5)
axes[0,0].legend()
txt = f'MEDIAN: {price_20.median()}\nMEAN: {price_20.mean():.2f}'
axes[0,0].text(10_000, 85_000, txt)

price_30.plot(kind='hist', bins=bins, ax=axes[0,1], title='Histogram of Price in Range [200, 30K]', xlabel='Price', color=colors_5[1])
axes[0,1].axvline(price_30.mean(), color='red', linestyle='dashed', linewidth=2, label='MEAN', alpha=.5)
axes[0,1].axvline(price_30.median(), color='red', linestyle='solid', linewidth=2, label='MEDIAN', alpha=.5)
axes[0,1].legend()
txt = f'MEDIAN: {price_30.median()}\nMEAN: {price_30.mean():.2f}'
axes[0,1].text(10_000, 85_000, txt)

price_40.plot(kind='hist', bins=bins, ax=axes[0,2], title='Histogram of Price in Range [200, 40K]', xlabel='Price', color=colors_5[2])
axes[0,2].axvline(price_40.mean(), color='red', linestyle='dashed', linewidth=2, label='MEAN', alpha=.5)
axes[0,2].axvline(price_40.median(), color='red', linestyle='solid', linewidth=2, label='MEDIAN', alpha=.5)
axes[0,2].legend()
txt = f'MEDIAN: {price_40.median()}\nMEAN: {price_40.mean():.2f}'
axes[0,2].text(10_000, 85_000, txt)

price_20.plot(kind='kde', ax=axes[1,0], title='KDE of Price in Range [200, 20K]', xlabel='Price',  color=colors_5[0])
axes[1,0].axvline(price_20.mean(), color='blue', linestyle='dashed', linewidth=2, label='MEAN', alpha=.5)
axes[1,0].axvline(price_20.median(), color='blue', linestyle='solid', linewidth=2, label='MEDIAN', alpha=.5)
axes[1,0].legend()

price_30.plot(kind='kde', ax=axes[1,1], title='KDE of Price in Range [200, 30K]', xlabel='Price',  color=colors_5[1])
axes[1,1].axvline(price_30.mean(), color='blue', linestyle='dashed', linewidth=2, label='MEAN', alpha=.5)
axes[1,1].axvline(price_30.median(), color='blue', linestyle='solid', linewidth=2, label='MEDIAN', alpha=.5)
axes[1,1].legend()

price_40.plot(kind='kde', ax=axes[1,2], title='KDE of Price in Range [200, 40K]', xlabel='Price',  color=colors_5[2])
axes[1,2].axvline(price_40.mean(), color='blue', linestyle='dashed', linewidth=2, label='MEAN', alpha=.5)
axes[1,2].axvline(price_40.median(), color='blue', linestyle='solid', linewidth=2, label='MEDIAN', alpha=.5)
axes[1,2].legend()

# %% [markdown]
# - #### **Drop null values**
# - #### **As mentioned above, the range of price will be set to`[200, 20K]`**
# - #### **Drop the extreme values of the `powerPS`**
# - #### **Drop the `postalCode`, `dateCreated`, `name`, and `monthOfRegistration` columns**
# - #### **Add a new column for the `age` of the car. Then drop the `yearOfRegistration` column**

# %%
# drop null values
df.dropna(inplace=True)

# Drop cars with unacceptable prices
df = df[df['price'].between(200, 20_000)]

# Drop cars with extreme powerPS
df = df[(df['powerPS'] > 0) & (df['powerPS'] <= 1000)]

# Add the 'age' column
current_year = 2025
df['age'] = current_year - df['yearOfRegistration']

# Drop unnecessary columns and rows
df.drop(['postalCode', 'dateCreated', 'name', 'monthOfRegistration', 'yearOfRegistration'], axis=1, inplace=True)
df = df[df['fuelType'] != 'Other']
df = df[df['notRepairedDamage'] != 'NaN']

# %%
df.head()
# Out:
#     price   abtest  vehicleType  gearbox  powerPS    model  kilometer  \
# 3    1500     test    small car  manuell       75     golf     150000
# 4    3600     test    small car  manuell       69    fabia      90000
# 5     650     test        sedan  manuell      102      3er     150000
# 6    2200     test  convertible  manuell      109  2_reihe     150000
# 10   2000  control        sedan  manuell      105  3_reihe     150000
#
#    fuelType       brand notRepairedDamage  age
# 3    petrol  volkswagen              nein   24
# 4    diesel       skoda              nein   17
# 5    petrol         bmw                ja   30
# 6    petrol     peugeot              nein   21
# 10   petrol       mazda              nein   21

# %%
df.nunique()
# Out:
# price                3282
# abtest                  2
# vehicleType             8
# gearbox                 2
# powerPS               426
# model                 248
# kilometer              13
# fuelType                7
# brand                  39
# notRepairedDamage       2
# age                    39
# dtype: int64

# %%
df['notRepairedDamage'] = df['notRepairedDamage'].dropna().map({'ja': 1, 'nein': 0}).astype(int)
df['abtest'] = df['abtest'].map({'test': 1, 'control': 0}).astype(int)
df['gearbox'] = df['gearbox'].map({'automatik': '1', 'manuell': '0'}).astype(int)

# %%
a = df[['abtest', 'price']]
methods = ['kendall', 'spearman', 'pearson']

fig, axes = plt.subplots(1, 3, figsize=(14, 4), sharey=True)
fig.suptitle('Correlations', fontweight='bold', fontsize='14')

for i in range(3):
    sns.heatmap(a.corr(method=methods[i]), annot=True, ax=axes[i])
    axes[i].set_title(f"Price vs. Month of Registration ({methods[i]})")

# %%
df.head()
# Out:
#     price  abtest  vehicleType  gearbox  powerPS    model  kilometer fuelType  \
# 3    1500       1    small car        0       75     golf     150000   petrol
# 4    3600       1    small car        0       69    fabia      90000   diesel
# 5     650       1        sedan        0      102      3er     150000   petrol
# 6    2200       1  convertible        0      109  2_reihe     150000   petrol
# 10   2000       0        sedan        0      105  3_reihe     150000   petrol
#
#          brand  notRepairedDamage  age
# 3   volkswagen                  0   24
# 4        skoda                  0   17
# 5          bmw                  1   30
# 6      peugeot                  0   21
# 10       mazda                  0   21

# %%
corr_col = ['abtest', 'gearbox', 'powerPS', 'kilometer', 'notRepairedDamage', 'age', 'price']
df_corr = df[corr_col].corr()

mask = np.triu(np.ones_like(df_corr, dtype='bool'))

plt.figure(figsize = (16,9))
plt.title("Feature Correlation Heatmap",fontsize=20)
sns.heatmap(
    df_corr,
    vmin=-1, vmax=1, center=0,
    cmap = sns.color_palette("vlag_r", as_cmap=True),
    square=True,
    annot=True,
    fmt='.3f',
    mask=mask
)
plt.show()

# %% [markdown]
# #### - **From the correlation matrix, I think we should make use of `gearbox`, `powerPS`, `kilometer` and `age` to predict `price`. I will drop `abtest` col.**
# #### - **I think the data itself is quite ready for this phase. However, I should apply Feature Scaling with Z-Score Norm**
# #### - **I will also split the data with a ratio of %70, %15, and %15.**

# %%
df.nunique()
# Out:
# price                3282
# vehicleType             8
# gearbox                 2
# powerPS               426
# model                 248
# kilometer              13
# fuelType                7
# brand                  39
# notRepairedDamage       2
# age                    39
# dtype: int64

# %%
df['fuelType'].value_counts()
# Out:
# fuelType
# petrol      150445
# diesel       75330
# lpg           3666
# cng            421
# hybrid         166
# electric        49
# other           48
# Name: count, dtype: int64

# %%
df = df.drop(columns=['abtest'], axis=1)
df.head()
# Out:
#     price  vehicleType  gearbox  powerPS    model  kilometer fuelType  \
# 3    1500    small car        0       75     golf     150000   petrol
# 4    3600    small car        0       69    fabia      90000   diesel
# 5     650        sedan        0      102      3er     150000   petrol
# 6    2200  convertible        0      109  2_reihe     150000   petrol
# 10   2000        sedan        0      105  3_reihe     150000   petrol
#
#          brand  notRepairedDamage  age
# 3   volkswagen                  0   24
# 4        skoda                  0   17
# 5          bmw                  1   30
# 6      peugeot                  0   21
# 10       mazda                  0   21

# %%
numerical_features = ['kilometer', 'powerPS', 'age']
categorical_features = ['vehicleType', 'fuelType', 'brand', 'model']

# %%
color_palette = sns.color_palette("pastel")
def plot_transformations(df, features, transformations=['original', 'boxcox', 'quantile', 'sqrt', 'log']):
    n_features = len(features)
    n_transforms = len(transformations)
    
    fig, axes = plt.subplots(n_features, n_transforms, figsize=(n_transforms*6, n_features*4))
    
    for i, feature in enumerate(features):
        for j, transform in enumerate(transformations):
            ax = axes[i, j] if n_features > 1 else axes[j]
            
            if transform == 'original':
                data = df[feature]
                title = f'Original - {feature}'
            elif transform == 'boxcox':
                data, _ = boxcox(df[feature] + 1)
                title = f'Box-Cox - {feature}'
            elif transform == 'quantile':
                transformer = QuantileTransformer(n_quantiles=100, output_distribution='normal')
                data = transformer.fit_transform(df[feature].values.reshape(-1, 1)).flatten()
                title = f'Quantile - {feature}'
            elif transform == 'sqrt':
                data = np.sqrt(df[feature])
                title = f'Square Root - {feature}'
            elif transform == 'log':
                data = np.log1p(df[feature])
                title = f'Log(x+1) - {feature}'
                
            skewness = stats.skew(data)
            
            sns.histplot(data, kde=True, bins=30, ax=ax, color=color_palette[i])
            ax.set_title(f'{title}\nSkewness: {skewness:.3f}')
            ax.set_xlabel(f'{transform.capitalize()} of {feature}')
            ax.set_ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()
    
plot_transformations(df, numerical_features)

# %% [markdown]
# We can apply normalization techniques to turn data distribution near to Guassian distribution

# %%
df_transformed = df.copy()

qt = QuantileTransformer(output_distribution='normal')
df_transformed['kilometer'] = qt.fit_transform(df[['kilometer']])


for col in ['powerPS', 'age']:
    df_transformed[col], _ = boxcox(df[col] + 1)


fig, axes = plt.subplots(2, len(numerical_features), figsize=(20, 8))

for i, col in enumerate(numerical_features):
    sns.histplot(df[col], kde=True, ax=axes[0, i])
    axes[0, i].set_title(f'Original {col}\nSkewness: {stats.skew(df[col]):.3f}')
    axes[0, i].set_xlabel(col)
    axes[0, i].set_ylabel('Frequency')
    
    sns.histplot(df_transformed[col], kde=True, ax=axes[1, i])
    axes[1, i].set_title(f'Transformed {col}\nSkewness: {stats.skew(df_transformed[col]):.3f}')
    axes[1, i].set_xlabel(col)
    axes[1, i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 6), tight_layout=True)
fig.subplots_adjust(hspace=0.5)

axes = axes.flatten()

for i, column in enumerate(numerical_features):
    sns.boxplot(x=df_transformed[column], ax=axes[i], color=color_palette[i])
    axes[i].set_title(f'Boxplot of {column}')
    axes[i].set_xlabel(column)

plt.show()

# %%
def IQR_limits(df, features):
    df_clean = df.copy()
    
    for feature in features:
        Q1 = df_clean[feature].quantile(0.25)
        Q3 = df_clean[feature].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = (df_clean[feature] < lower_bound) | (df_clean[feature] > upper_bound)
        print(f"Number of outliers in '{feature}' column: {outliers.sum()}")

        df_clean = df_clean[~outliers]
    
    return df_clean

# %% [markdown]
# PowerPS have a large number of outliers, so we should consider remove outliers in this feature.

# %%
df_test = df_transformed.copy(deep=True)
df_test = IQR_limits(df_test, ['powerPS'])
# Out:
# Number of outliers in 'powerPS' column: 795

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 6), tight_layout=True)
fig.subplots_adjust(hspace=0.5)

axes = axes.flatten()

for i, column in enumerate(numerical_features):
    sns.boxplot(x=df_test[column], ax=axes[i], color=color_palette[i])
    axes[i].set_title(f'Boxplot of {column}')
    axes[i].set_xlabel(column)

plt.show()

# %%
df_test.to_csv("/kaggle/working/data.csv", index=False)

# %% [markdown]
# # Modeling
#
# ## In this phase, I'm going to train different models in order to predict the price of a used car based on other features. I plan to use:
# #### - Conventional ML methods for regression
# #### - Ensembling

# %% [markdown]
# ## **Machine learning**
# - **Regression Models:** Decision Tree, Random Forest, Extra Trees, AdaBoost, XGBoost, CatBoost, and KNeighbors
# - **Metrics:** MSE, MAE, and $R^2\textrm{-}Score$
# - Cross-validation

# %%
models = {
    'KNN': KNeighborsRegressor(n_neighbors=5),
    'XGBoost': XGBRegressor(random_state=42, tree_method="gpu_hist", predictor="gpu_predictor"),
    'Random Forest': RandomForestRegressor(random_state=42),
    # 'Gradient Boosting': GradientBoostingRegressor(random_state=42),
    # 'Extra Trees': ExtraTreesRegressor(random_state=42)
    # 'Linear Regression': LinearRegression(),
}

# %%
scoring = {"R2":make_scorer(r2_score),
            "MAE":make_scorer(mean_absolute_error),
            "MSE":make_scorer(mean_squared_error)}

# %%
X = df_test.drop(['price'], axis=1)
y = df_test['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)
print(f"Train Shape: {X_train.shape}\nTest Shape: {X_test.shape}")
# Out:
# Train Shape: (183464, 9)
# Test Shape: (45866, 9)

# %%
df_dummies = pd.get_dummies(df_test, drop_first=True)
print(f"Shape of the DataFrame with Dummies: {df_dummies.shape}")
df_dummies.head()
# Out:
# Shape of the DataFrame with Dummies: (229330, 304)
#     price  gearbox   powerPS  kilometer  notRepairedDamage       age  \
# 3    1500        0  4.872407   5.199338                  0  5.719271
# 4    3600        0  4.769001  -0.922330                  0  4.822865
# 5     650        0  5.258620   5.199338                  1  6.360897
# 6    2200        0  5.342982   5.199338                  0  5.358906
# 10   2000        0  5.295420   5.199338                  0  5.358906
#
#     vehicleType_convertible  vehicleType_coupe  vehicleType_other  \
# 3                     False              False              False
# 4                     False              False              False
# 5                     False              False              False
# 6                      True              False              False
# 10                    False              False              False
#
#     vehicleType_sedan  ...  brand_saab  brand_seat  brand_skoda  brand_smart  \
# 3               False  ...       False       False        False        False
# 4               False  ...       False       False         True        False
# 5                True  ...       False       False        False        False
# 6               False  ...       False       False        False        False
# 10               True  ...       False       False        False        False
#
#     brand_subaru  brand_suzuki  brand_toyota  brand_trabant  brand_volkswagen  \
# 3          False         False         False          False              True
# 4          False         False         False          False             False
# 5          False         False         False          False             False
# 6          False         False         False          False             False
# 10         False         False         False          False             False
#
#     brand_volvo
# 3         False
# 4         False
# 5         False
# 6         False
# 10        False
#
# [5 rows x 304 columns]

# %% [markdown]
# # Preprocessing Pipeline

# %%
numerical_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

final_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('pca', PCA()),
])

# %% [markdown]
# ## Test for number of components to achieve 95% of variance explained

# %%
X_transformed = final_pipeline.fit_transform(X_train)
pca = final_pipeline.named_steps['pca']

cumulative_variance = pca.explained_variance_ratio_.cumsum()
# Find where variance exceeds 95%
components_95pct = next(i for i, var in enumerate(cumulative_variance) if var >= 0.95)

fig, ax = plt.subplots(figsize=(20, 6))
sns.set(font_scale=1)

# Plot cumulative variance
plt.step(range(X_transformed.shape[1]), cumulative_variance, where='mid',
         label='cumulative explained variance')
         
# Plot individual variance
sns.barplot(pca.explained_variance_ratio_, alpha=0.5, color='g',
            label='individual explained variance')

plt.xlim(0, 100)

# Add horizontal line at 95% variance
plt.axhline(y=0.95, color='r', linestyle='--', label='95% explained variance')

# Add vertical line at number of components needed for 95% variance
plt.axvline(x=components_95pct, color='purple', linestyle='--', 
            label=f'Components needed: {components_95pct}')

ax.set_xticklabels([s if int(s.get_text())%2 == 0 else '' for s in ax.get_xticklabels()])

plt.ylabel('Explained variance', fontsize=14)
plt.xlabel('Principal components', fontsize=14)
plt.legend(loc='best', fontsize=13)
plt.title(f'PCA Analysis: {components_95pct} components needed for 95% variance', fontsize=16)
plt.grid()
# Out:
# [2025-03-20 15:42:29.496] [CUML] [warning] Warning(`fit`): As of v0.16, PCA invoked without an n_components argument defaults to using min(n_samples, n_features) rather than 1

# %%
final_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=58)),
])

# %% [markdown]
# So, we need keep 58 components to achieve 95% of variance explained

# %% [markdown]
# # Cross validating

# %%
results = {'Model': [], 'R2 (Test)': [], 'MAE (Test)': [], 'MSE (Test)': [], 'Score Time': [], 'R2 (Train)': [], 'MAE (Train)': [], 'MSE (Train)': [], 'Train Time': []}
kf = KFold(n_splits=10, shuffle=True, random_state=42)

for name, model in models.items():
    print(f"Cross validate {name}...")
    
    model_pipeline = Pipeline(steps=[('final_pipeline', final_pipeline), ('model', model)])

    cv_results = cross_validate(model_pipeline, X, y, cv=kf, scoring=scoring, return_train_score=True)
    print("_"*50)

    results['Model'].append(name)
    results['R2 (Test)'].append(cv_results['test_R2'].mean())
    results['MAE (Test)'].append(cv_results['test_MAE'].mean())
    results['MSE (Test)'].append(cv_results['test_MSE'].mean())
    results['Score Time'].append(cv_results['score_time'].mean())

    results['R2 (Train)'].append(cv_results['train_R2'].mean())
    results['MAE (Train)'].append(cv_results['train_MAE'].mean())
    results['MSE (Train)'].append(cv_results['train_MSE'].mean())
    results['Train Time'].append(cv_results['fit_time'].mean())

print("Cross validating completed.")
# Out:
# Cross validate KNN...
# [2025-03-20 15:44:52.875] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 15:45:01.463] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 15:45:09.691] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 15:45:17.981] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 15:45:26.389] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 15:45:34.729] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 15:45:43.088] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 15:45:51.448] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 15:45:59.811] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 15:46:08.174] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# __________________________________________________
# Cross validate XGBoost...
# __________________________________________________
# Cross validate Random Forest...
# __________________________________________________
# Cross validating completed.

# %%
results_df = pd.DataFrame(results)
results_df.sort_values(by="MAE (Test)", ascending=True)
# Out:
#            Model  R2 (Test)   MAE (Test)    MSE (Test)  Score Time  \
# 1        XGBoost   0.883008  1048.886496  2.586016e+06    0.192390
# 0            KNN   0.875022  1062.590594  2.762444e+06    0.663467
# 2  Random Forest   0.877470  1082.362839  2.708211e+06    0.951138
#
#    R2 (Train)  MAE (Train)   MSE (Train)  Train Time
# 1    0.901835   988.294578  2.169905e+06    3.500700
# 0    0.907167   920.319409  2.052028e+06    1.919038
# 2    0.917389   929.491230  1.826096e+06    4.111608

# %% [markdown]
# - XGBoost is the best model with balance in performance and inference + training time
# - KNN is the fastest model in training time with pretty good performance
# - Random Forest which is slightly better than KNN in R2 score but its training and inference time is quite slowly

# %% [markdown]
# # **Hyperparameter Tuning**
# - **RandomizedSearchCV**
# - **GridSearchCV**

# %%
print(f"KNN's hyperparamter:\n{models['KNN'].get_params()}\n")
print(f"XGBoost's hyperparamter:\n{models['XGBoost'].get_params()}\n")
print(f"Random Forest's hyperparamter:\n{models['Random Forest'].get_params()}\n")
# Out:
# KNN's hyperparamter:
# {'handle': <pylibraft.common.handle.Handle object at 0x7b1ae386b7b0>, 'verbose': 4, 'output_type': 'input', 'n_neighbors': 5, 'algorithm': 'auto', 'metric': 'euclidean', 'p': 2, 'metric_params': None, 'algo_params': None, 'n_jobs': None, 'weights': 'uniform'}
#
# XGBoost's hyperparamter:
# {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': None, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': None, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': 'gpu_hist', 'validate_parameters': None, 'verbosity': None, 'predictor': 'gpu_predictor'}
#
# Random Forest's hyperparamter:
# {'handle': <pylibraft.common.handle.Handle object at 0x7b1ae3869590>, 'verbose': 4, 'output_type': 'input', 'n_estimators': 100, 'max_depth': 16, 'max_features': 'sqrt', 'n_bins': 128, 'split_criterion': 2, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_impurity_decrease': 0.0, 'bootstrap': True, 'max_samples': 1.0, 'max_leaves': -1, 'accuracy_metric': 'r2', 'max_batch_size': 4096, 'n_streams': 4, 'dtype': None, 'min_weight_fraction_leaf': None, 'n_jobs': None, 'max_leaf_nodes': None, 'min_impurity_split': None, 'oob_score': None, 'random_state': 42, 'warm_start': None, 'class_weight': None, 'criterion': None}

# %%
param_distributions = {
    'KNN': {
        'model__n_neighbors': [3, 5, 8, 10, 15, 20],
    },
    'XGBoost': {
        'model__n_estimators': [300, 500, 800, 1000],
        'model__max_depth': [5, 10, 20],
        "model__learning_rate": [0.001, 0.05, 0.1],
    },
    'Random Forest': {
        'model__n_estimators': [50, 100, 150, 200],
        'model__max_depth': [5, 15]
    },
}

# %%
best_models = {}

kf=KFold(n_splits=5, shuffle=True, random_state=42)

for name, model in models.items():
    print(f"Tuning {name}...")

    model_pipeline = Pipeline(steps=[("final_pipeline", final_pipeline), ("model", model)])

    random_search = RandomizedSearchCV(
        model_pipeline,
        param_distributions[name],
        n_iter=5,
        scoring=scoring,
        refit="R2",  
        cv=kf,
        # n_jobs=-1,
        random_state=42,
        return_train_score=True,
        verbose=2
    )

    random_search.fit(X_train, y_train)

    best_models[name] = random_search.best_estimator_
    print(f"Best Params for {name}: {random_search.best_params_}")
    print(f"Best R2 Score: {random_search.best_score_}\n")

best_model_name = max(best_models, key=lambda name: best_models[name].score(X_test, y_test))
best_model = best_models[best_model_name]

y_pred = best_model.predict(X_test)
print(f"Best Model: {best_model_name}")
print(f"Test R2 Score: {best_model.score(X_test, y_test)}")
# Out:
# Tuning KNN...
# [2025-03-20 16:20:15.952] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [2025-03-20 16:20:15.972] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=3; total time=   2.4s
# [2025-03-20 16:20:21.775] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=3; total time=   2.3s
# [2025-03-20 16:20:27.492] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=3; total time=   2.3s
# [2025-03-20 16:20:33.290] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=3; total time=   2.2s
# [2025-03-20 16:20:39.115] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=3; total time=   2.3s
# [2025-03-20 16:20:44.948] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=5; total time=   2.3s
# [2025-03-20 16:20:50.868] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=5; total time=   2.3s
# [2025-03-20 16:20:56.676] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=5; total time=   2.3s
# [2025-03-20 16:21:02.486] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=5; total time=   2.3s
# [2025-03-20 16:21:08.236] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=5; total time=   2.2s
# [2025-03-20 16:21:13.936] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=20; total time=   2.3s
# [2025-03-20 16:21:19.854] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=20; total time=   2.2s
# [2025-03-20 16:21:25.629] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=20; total time=   2.2s
# [2025-03-20 16:21:31.424] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=20; total time=   2.2s
# [2025-03-20 16:21:37.250] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=20; total time=   2.2s
# [2025-03-20 16:21:43.055] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=8; total time=   2.3s
# [2025-03-20 16:21:48.902] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=8; total time=   2.2s
# [2025-03-20 16:21:54.687] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=8; total time=   2.2s
# [2025-03-20 16:22:00.475] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=8; total time=   2.2s
# [2025-03-20 16:22:06.246] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ...............................model__n_neighbors=8; total time=   2.3s
# [2025-03-20 16:22:12.065] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=15; total time=   2.3s
# [2025-03-20 16:22:17.949] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=15; total time=   2.3s
# [2025-03-20 16:22:23.807] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=15; total time=   2.2s
# [2025-03-20 16:22:29.639] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=15; total time=   2.4s
# [2025-03-20 16:22:35.676] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV] END ..............................model__n_neighbors=15; total time=   2.3s
# [2025-03-20 16:22:41.629] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 16:22:41.630] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# Best Params for KNN: {'model__n_neighbors': 8}
# Best R2 Score: 0.8720493575169457
#
# Tuning XGBoost...
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END model__learning_rate=0.1, model__max_depth=20, model__n_estimators=1000; total time= 3.2min
# [CV] END model__learning_rate=0.1, model__max_depth=20, model__n_estimators=1000; total time= 3.1min
# [CV] END model__learning_rate=0.1, model__max_depth=20, model__n_estimators=1000; total time= 3.2min
# [CV] END model__learning_rate=0.1, model__max_depth=20, model__n_estimators=1000; total time= 3.2min
# [CV] END model__learning_rate=0.1, model__max_depth=20, model__n_estimators=1000; total time= 3.2min
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   4.1s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   4.3s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   4.1s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   4.1s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   4.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=800; total time=   5.2s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=800; total time=   5.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=800; total time=   5.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=800; total time=   5.3s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=800; total time=   5.3s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=800; total time=  16.0s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=800; total time=  15.9s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=800; total time=  15.9s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=800; total time=  16.0s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=800; total time=  15.8s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   8.3s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   8.7s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   8.3s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   8.5s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   8.7s
# Best Params for XGBoost: {'model__n_estimators': 300, 'model__max_depth': 10, 'model__learning_rate': 0.05}
# Best R2 Score: 0.8895238068323582
#
# Tuning Random Forest...
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ........model__max_depth=5, model__n_estimators=100; total time=   2.1s
# [CV] END ........model__max_depth=5, model__n_estimators=100; total time=   2.1s
# [CV] END ........model__max_depth=5, model__n_estimators=100; total time=   2.1s
# [CV] END ........model__max_depth=5, model__n_estimators=100; total time=   2.3s
# [CV] END ........model__max_depth=5, model__n_estimators=100; total time=   2.1s
# [CV] END .......model__max_depth=15, model__n_estimators=100; total time=   3.5s
# [CV] END .......model__max_depth=15, model__n_estimators=100; total time=   3.4s
# [CV] END .......model__max_depth=15, model__n_estimators=100; total time=   3.6s
# [CV] END .......model__max_depth=15, model__n_estimators=100; total time=   3.3s
# [CV] END .......model__max_depth=15, model__n_estimators=100; total time=   3.4s
# [CV] END .........model__max_depth=5, model__n_estimators=50; total time=   1.9s
# [CV] END .........model__max_depth=5, model__n_estimators=50; total time=   2.0s
# [CV] END .........model__max_depth=5, model__n_estimators=50; total time=   2.0s
# [CV] END .........model__max_depth=5, model__n_estimators=50; total time=   2.0s
# [CV] END .........model__max_depth=5, model__n_estimators=50; total time=   2.0s
# [CV] END .......model__max_depth=15, model__n_estimators=200; total time=   5.7s
# [CV] END .......model__max_depth=15, model__n_estimators=200; total time=   5.7s
# [CV] END .......model__max_depth=15, model__n_estimators=200; total time=   5.8s
# [CV] END .......model__max_depth=15, model__n_estimators=200; total time=   5.6s
# [CV] END .......model__max_depth=15, model__n_estimators=200; total time=   5.6s
# [CV] END ........model__max_depth=5, model__n_estimators=150; total time=   2.5s
# [CV] END ........model__max_depth=5, model__n_estimators=150; total time=   2.6s
# [CV] END ........model__max_depth=5, model__n_estimators=150; total time=   2.5s
# [CV] END ........model__max_depth=5, model__n_estimators=150; total time=   2.6s
# [CV] END ........model__max_depth=5, model__n_estimators=150; total time=   2.5s
# Best Params for Random Forest: {'model__n_estimators': 200, 'model__max_depth': 15}
# Best R2 Score: 0.8654362164054785
#
# Best Model: XGBoost
# Test R2 Score: 0.8923730576357752

# %%
tuned_models = {
    'KNN': KNeighborsRegressor(n_neighbors=8),
    'XGBoost': XGBRegressor(random_state=42, tree_method="gpu_hist", predictor="gpu_predictor", n_estimators=300, max_depth=10, learning_rate= 0.05),
    'Random Forest': RandomForestRegressor(random_state=42, n_estimators=200, max_depth=15),
}

# %% [markdown]
# # Training

# %%
fit_results = {'Model': [], 'R2 (Test)': [], 'MAE (Test)': [], 'MSE (Test)': [], 'R2 (Train)': [], 'MAE (Train)': [], 'MSE (Train)': []}

for name, model in models.items():
    print(f"Fitting {name}...")

    model_pipeline = Pipeline(steps=[
        ('final_pipeline', final_pipeline),
        ('model', model)
    ])
    
    model_pipeline.fit(X_train, y_train)
    y_pred = model_pipeline.predict(X_test)

    r2_test = r2_score(y_test, y_pred)
    mae_test = mean_absolute_error(y_test, y_pred)
    mse_test = mean_squared_error(y_test, y_pred)

    fit_results['Model'].append(name)
    fit_results['R2 (Test)'].append(r2_test)
    fit_results['MAE (Test)'].append(mae_test)
    fit_results['MSE (Test)'].append(mse_test)

    y_train_pred = model_pipeline.predict(X_train)
    fit_results['R2 (Train)'].append(r2_score(y_train, y_train_pred))
    fit_results['MAE (Train)'].append(mean_absolute_error(y_train, y_train_pred))
    fit_results['MSE (Train)'].append(mean_squared_error(y_train, y_train_pred))

print("Fitting completed.")
fit_results_df = pd.DataFrame(fit_results)
# Out:
# Fitting KNN...
# Fitting XGBoost...
# Fitting Random Forest...
# Fitting completed.

# %%
pd.options.display.float_format="{:.6f}".format

# %%
fit_results_df.sort_values(by='R2 (Test)', ascending=False)
# Out:
#            Model  R2 (Test)  MAE (Test)     MSE (Test)  R2 (Train)  \
# 1        XGBoost   0.882635 1053.974364 2587548.753203    0.902500
# 2  Random Forest   0.875812 1094.491867 2737971.413310    0.917526
# 0            KNN   0.874388 1066.992587 2769365.629529    0.906716
#
#    MAE (Train)    MSE (Train)
# 1   985.486701 2156612.175849
# 2   929.655463 1824255.884099
# 0   923.139128 2063345.864011

# %%
fit_results_df.sort_values(by='MSE (Test)', ascending=True)
# Out:
#            Model  R2 (Test)  MAE (Test)     MSE (Test)  R2 (Train)  \
# 1        XGBoost   0.882635 1053.974364 2587548.753203    0.902500
# 2  Random Forest   0.875812 1094.491867 2737971.413310    0.917526
# 0            KNN   0.874388 1066.992587 2769365.629529    0.906716
#
#    MAE (Train)    MSE (Train)
# 1   985.486701 2156612.175849
# 2   929.655463 1824255.884099
# 0   923.139128 2063345.864011

# %% [markdown]
# We can continue optimize and improve the performance of models; however, to simplify this notebook, I will stop here and go to next step

# %% [markdown]
# # **Ensemble Learning**
#
# ### Voting
# ### Stacking

# %%
X_train_processed = final_pipeline.fit_transform(X_train)
X_test_processed = final_pipeline.transform(X_test)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
def show_results(y_test, y_pred):
    results = {'R2 (Test)': r2_score(y_test, y_pred), 'MAE (Test)': mean_absolute_error(y_test, y_pred), 'MSE (Test)': mean_squared_error(y_test, y_pred)}
    return results

# %% [markdown]
# ## Voting

# %%
# %%time

voting_regressor = VotingRegressor(estimators=list(models.items()))
voting_regressor.fit(X_train_processed, y_train)
y_pred_voting = voting_regressor.predict(X_test_processed)
show_results(y_test, y_pred_voting)
# Out:
# [2025-03-20 17:10:33.862] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# CPU times: user 10.1 s, sys: 2.62 s, total: 12.7 s
# Wall time: 5.12 s
# {'R2 (Test)': 0.8886965163326466,
#  'MAE (Test)': 1021.1559659668882,
#  'MSE (Test)': 2453908.3723726133}

# %% [markdown]
# ## Stacking

# %%
from cuml import Ridge, Lasso, ElasticNet

# %%
# %%time

stacking_regressor = StackingRegressor(
    estimators=list(models.items()),
    final_estimator=LinearRegression(algorithm='svd', copy_X= True, fit_intercept= True, normalize= True)
)
stacking_regressor.fit(X_train_processed, y_train)


y_pred_stacking = stacking_regressor.predict(X_test_processed)
show_results(y_test, y_pred_stacking)
# Out:
# [2025-03-20 18:03:23.089] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 18:03:26.786] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 18:03:26.793] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 18:03:27.490] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 18:03:28.182] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 18:03:28.870] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [2025-03-20 18:03:29.565] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# CPU times: user 53.7 s, sys: 15.8 s, total: 1min 9s
# Wall time: 28 s
# {'R2 (Test)': 0.8895512497002519,
#  'MAE (Test)': 1014.5034847406941,
#  'MSE (Test)': 2435064.062223424}

# %% [markdown]
# Ridge:
# {'R2 (Test)': 0.889551249700258,
#  'MAE (Test)': 1014.5034847406374,
#  'MSE (Test)': 2435064.062223289}
#
# Lasso:
# {'R2 (Test)': 0.8894959110048466,
#  'MAE (Test)': 1014.8951910122453,
#  'MSE (Test)': 2436284.114673688}
#
# ElasticNet:
# {'R2 (Test)': 0.8894959120571199,
#  'MAE (Test)': 1014.8951828237322,
#  'MSE (Test)': 2436284.091474215}
#
#  LinearRegression:
#  {'R2 (Test)': 0.8895512497002506,
#  'MAE (Test)': 1014.5034847406878,
#  'MSE (Test)': 2435064.062223454}

# %%
# param_grid = {
#     'alpha': [0.8, 1, 5, 10],
#     'solver': ['eig', 'svd', 'cd'],
#     'fit_intercept': [True, False],
#      'normalize': [True, False],
# }

param_grid = {
    'algorithm': ['svd', 'eig', 'qr', 'svd-qr', 'svd-jacobi'],
    'fit_intercept': [True, False],
    'copy_X': [True, False],
    'normalize': [True, False]
}

# %%
model = LinearRegression()
model.get_params()
# Out:
# {'handle': <pylibraft.common.handle.Handle at 0x7b1ae377e370>,
#  'verbose': 4,
#  'output_type': 'input',
#  'algorithm': 'eig',
#  'fit_intercept': True,
#  'copy_X': True,
#  'normalize': False}

# %%
grid_search = GridSearchCV(
    model,
    param_grid,
    cv=kf,
    scoring=scoring,
    refit="R2",
    verbose=2
)

grid_search.fit(X_train_processed, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=True; total time=   0.5s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=eig, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-qr, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=True, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=True, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=True; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# [CV] END algorithm=svd-jacobi, copy_X=False, fit_intercept=False, normalize=False; total time=   0.3s
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=LinearRegression(),
#              param_grid={'algorithm': ['svd', 'eig', 'qr', 'svd-qr',
#                                        'svd-jacobi'],
#                          'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'normalize': [True, False]},
#              refit='R2',
#              scoring={'MAE': make_scorer(mean_absolute_error),
#                       'MSE': make_scorer(mean_squared_error),
#                       'R2': make_scorer(r2_score)},
#              verbose=2)

# %%
best_model = grid_search.best_estimator_
print(f"Best Params: {grid_search.best_params_}")
print(f"Best R2 Score: {grid_search.best_score_}\n")

# Eval
y_pred = best_model.predict(X_test_processed)
print(f"Test R2 Score: {r2_score(y_test, y_pred)}")
print(f"Test MSE: {mean_squared_error(y_test, y_pred)}")
print(f"Test MAE: {mean_absolute_error(y_test, y_pred)}")
# Out:
# Best Params: {'algorithm': 'svd', 'copy_X': True, 'fit_intercept': True, 'normalize': True}
# Best R2 Score: 0.7251162444752645
#
# Test R2 Score: 0.725879117726995
# Test MSE: 6043544.243972262
# Test MAE: 1809.8994250548103

# %%
import joblib
joblib.dump(final_pipeline, "/kaggle/working/preprocessor.pkl")
joblib.dump(tuned_models['XGBoost'], "/kaggle/working/xgb_88.pkl")
joblib.dump(tuned_models["Random Forest"], "/kaggle/working/random_forest_87.pkl")
joblib.dump(tuned_models["KNN"], "/kaggle/working/knn_87.pkl")
joblib.dump(stacking_regressor, "/kaggle/working/stacklinear_reg_89.pkl")
# Out:
# ['/kaggle/working/stacklinear_reg_89.pkl']
